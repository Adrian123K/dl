# %% [markdown]
# ## <b>■ 3장. 신경망</b>
#     신경망 안에 들어가는 함수 소개
#         1. 활상화 함수
#             - 계단함수
#             - 시그모이드 함수
#             -  ReLU 함수
#         2. 출력층 함수
#             - 항등 함수
#             - 소프트맥스 함수
#         3. 오차함수
#
#     이 책은 전부 파이썬 날코딩으로 일일이 신경망을 만든다.
#     그리고서 나중에 tensorflow나 pytorch 사용해야 이해하면서 코딩할 수 있다.
#
# ### <b>■ 계단함수 (p.69)</b>
#     숫자 0과 1을 리턴하는 함수
#         x <= 0 -> return 0
#         x >0   -> return 1

# %% [markdown]
# ### ※ 문제23. 계단함수를 파이썬으로 구현하시오

# %%
def step_function(x):
    if x > 0 :
        return 1
    else:
        return 0
import numpy as np

x_data = np.array([-1,0,1])
print(step_function(x_data))
# Out:
# [0 0 1]

# %% [markdown]
#     위와 같이 계단함수를 만듣ㄹ면 step_function에서 numpy 배열은 넣을 수 없다

# %%
def step_function(x):
    y = x > 0
    return y.astype(int) # y가 true이면 1이 리턴, 아니면 0이 리컨

import numpy as np

x_data = np.array([-1,0,1])
print(step_function(x_data))
# Out:
# [0 0 1]

# %% [markdown]
# ### ※ 문제24. 계단함수 그래프를 직접 그리시오

# %%
import matplotlib.pyplot as plt
import numpy as np

def step_func(x):
    y = x>0
    return y.astype(int)

x = np.arange(-5.0,5.0,0.01)
y = step_func(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### ※ 문제25. 시그모이드 함수를 파이썬으로 구현하시오 (p.72)

# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))

x = np.array([0,1,2])
print(sigmoid(x))
# Out:
# [0.5        0.73105858 0.88079708]

# %% [markdown]
# ### ※ 문제26. 책 73페이지에 나오는 시그모이드 함수 그래프를 직접 그리시오

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams.update({'font.size': 22})

def sigmoid(x):
    return 1/(1+np.exp(-x))

X = np.arange(-5.0, 5.0, 0.1)
y = sigmoid(X)

plt.plot(X,y)
plt.ylim(-0.1, 1.1)
plt.show()

# %% [markdown]
# ### ※ 문제27. 오즈비율 함수 그래프를 그리시오

# %%
import numpy as np
def odds_function(p):
    return  p/(1-p)

x = np.arange(-5.0,5.0,0.001)
y = odds_function(x)
plt.plot(x,y)
plt.xlim(-0,1)
plt.ylim(-0,10)
plt.show()

# %% [markdown]
# ### ※ 문제28. 로짓함수도 그래프로 시각화 하시오

# %%
import matplotlib.pyplot as plt
import numpy as np

def logit(x):
    return np.log(x/(1-x))

x=np.arange(0.01,1,0.01)
y=logit(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### <b>■ ReLU 함수 (Recified Linear Unit)</b>
#     정류는 전기회로쪽 용어로 예를들어 반파정류회로는 +/- 가 반복되는 교류에서 흐름을 차단하는 회로
#     ReLU 함수 그래프처럼 x가 0 이하일 때 를 차단하여 아무런 값도 출력하지 않는 것(0을 출력)
#     ReLU 함수는 입력이 0을 넘으면 그 입력을 그대로 출력하고 0 이하면 0을 출력하는 함수

# %%
# 예제1. ReLU함수를 생성하시오
import numpy as np
def relu(x):
    return np.maximum(0,x) # 0과 x중 큰 값을 출력

print(relu(-2))
print(relu(0.3))
# Out:
# 0
# 0.3

# %% [markdown]
# ### ※ 문제29. ReLU함수의 그래프를 시각화 하시오

# %%
import matplotlib.pyplot as plt
import numpy as np

def relu(x):
    return np.maximum(0,x)

x = np.arange(-5.0,5.0,0.01)
y = relu(x)

plt.plot(x,y)
plt.show()

# %% [markdown]
# ### <b>■ 다차원 배열의 계산</b>
#     다차원 배열도 그 기본은 '숫자의 집합'
#     숫자가 한줄로 늘어선 것이나 정사각형으로 늘어놓은 것이나 3차원으로 늘어놓은 것이나 모두 다차원 배열

# %%
# 예제1. 1차원 배열 만드는 방법
import numpy as np
a = np.array([1,2,3,4])
np.ndim(a)
# Out:
# 1

# %%
# 아래의 2차원 배열을 생성하시오
b = np.array([1,2,3,4,5,6]).reshape(3,2)
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
# 위의 내적을 총 3가지 방법으로 구현하시오
# 첫번째 방법 : array 내적
import numpy as np
x = np.array([1,2,3,4]).reshape(2,2)
y = np.array([5,6,7,8]).reshape(2,2)
print(np.dot(x,y))
print('\n')

# 두번째 방법 : 행렬 곱
x = np.matrix([1,2,3,4]).reshape(2,2)
y = np.matrix([5,6,7,8]).reshape(2,2)
print(x*y)
print('\n')

# 세번째 방법 : 
import numpy as np
x = np.array([1,2,3,4]).reshape(2,2)
y = np.array([5,6,7,8]).reshape(2,2)
print(x@y)
# Out:
# [[19 22]
#  [43 50]]
#
#
# [[19 22]
#  [43 50]]
#
#
# [[19 22]
#  [43 50]]

# %% [markdown]
#     array와 matrix의 차이
#         array는 다차원으로 나타낼 수 있는데 matrix는 2차원 밖에 안된다.

# %% [markdown]
# #### 행렬곱(내적) 시 주의사항
# ![fig3-12](dl_images/fig3-12.png)
#
#     다차원 배열의 곱이 가능한 경우
#
# $$ \begin{pmatrix} 1 & 2 & 3 \\ 4 & 5 & 6 \\ \end{pmatrix} \begin{pmatrix} 1 & 2 \\ 3 & 4 \\ 5 & 6 \\ \end{pmatrix}$$
#
#     다차원 배열의 곱이 불가능한 경우

# %% [markdown]
# ### <b>■ 3층 신경망 구현하기</b>
# ![fig3-15](dl_images/fig3-15(e2.png)

# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))

x = np.array([1,2])
w1 = np.array([1,3,5,2,4,6]).reshape(2,3)

k = np.dot(x,w1)
k_p = sigmoid(k)
print(k_p)

w2 = np.array([6,7,8,9,10,11]).reshape(3,2)

m = np.dot(k_p,w2)
m_p = sigmoid(m)
print(m_p)

w3 = np.array([5,6,7,8]).reshape(2,2)
y = np.dot(m_p, w3)
print(y)

def softmax(x):
    m = np.max(x)
    exp_x = np.exp(x-m)
    sum_exp_x = np.sum(exp_x)
    y = exp_x / sum_exp_x
    return y

y_p = softmax(y)
print(y_p)
# Out:
# [0.99330715 0.9999833  0.99999996]
# [1. 1.]
# [12. 14.]
# [0.11920292 0.88079708]

# %% [markdown]
# ### <b>■ 출력층 설계하기 (p.90)</b>
#     출력층 함수는 그동안 흘러왔던 확률들의 숫자를 취합해서 결론을 내줘야하는 함수
#         1.회귀 : 항등함수 - 입력값을 받아서 그대로 출력하는 함수
#         2.분류 : 소프트맥스 함수 - 입력값을 받아서 확률벡터로 출력하는 함수
#
# ### <b>■ 소프트맥스 함수 수학식을 컴퓨터로 구현할 때 주의사항</b>
# ![e3-10](dl_images/e3.10.png)
#
#     위의 식을 파이썬으로 그대로 만들면 에러가 나서 구현이 안됨
#     지수함수는 쉽게 아주 큰 값을 출력하기 때문에 컴퓨터는 큰 값이 출력되면 overflow가 출력되며 에러가 발생
#     그래서 수학식을 아래와 같이 전개해줘야 한다.
#
# ![e3-11](dl_images/e3.11.png)
#
#     소프트맥스 함수는 지수함수를 사용하면 이 지수함수를 사용하면 아주 큰 값을 출력
#     자연상수 e의 10제곱은 20000이 넘고 e의 100제곱은 숫자 40개가 넘고 e의 1000제곱은 무한대를 뜻하는 inf가 출력되어 돌아오기 때문에 계산할 수 없다.
#     따라서 상수값을 빼서 값을 줄여줘야 한다.

# %%
import numpy as np
np.exp(12)
# Out:
# 162754.79141900392

# %%
import numpy as np
print(np.exp(10)) # 22026.465794
print(np.exp(100)) # 2.6881171418161356e+43
print(np.exp(1000)) # inf
# Out:
# 22026.465794806718
# 2.6881171418161356e+43
# inf
# C:\Users\knitwill\anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: overflow encountered in exp
#   after removing the cwd from sys.path.

# %% [markdown]
#     해결
#         입력신호 중에 최대값을 이용해서 입력신호들을 입력신호 중의 최대값으로 각각 빼준다.

# %%
import numpy as np
a = np.array([1010,1000,990])
C = np.max(a)
minus = a-C
print(np.exp(a))
print(np.exp(minus))
# Out:
# [inf inf inf]
# [1.00000000e+00 4.53999298e-05 2.06115362e-09]
# C:\Users\knitwill\anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in exp
#   """

# %% [markdown]
#     위의 식을 이용해서 소프트맥스 함수를 구현하기

# %%
import numpy as np
def softmax(x):
    mx = np.max(x)
    exp_x = np.exp(x-mx)
    sum_exp_x = np.sum(exp_x)
    y = exp_x / sum_exp_x
    return y

a = np.array([1010,1000,990])
softmax(a)
# Out:
# array([9.99954600e-01, 4.53978686e-05, 2.06106005e-09])

# %% [markdown]
# ### ※ 문제30. 아래의 리스트의 요소를 다 더하면 1이 되는지 확인하시오

# %%
import numpy as np
def softmax(x):
    mx = np.max(x)
    exp_x = np.exp(x-mx)
    sum_exp_x = np.sum(exp_x)
    y = exp_x / sum_exp_x
    return y

a = np.array([1010,1000,990])
sum(softmax(a))
# Out:
# 1.0

# %% [markdown]
# ### ※ 문제31. (오늘의 마지막 문제) 출력층의 y가 softmax 함수를 통과했을 때 나오는 확률벡터를 구하시오

# %%
import numpy as np

def sigmoid(x):
    return 1/(1+np.exp(-x))

x = np.array([1,2])
w1 = np.array([1,3,5,2,4,6]).reshape(2,3)

k = np.dot(x,w1)
k_p = sigmoid(k)
print(k_p) # 은닉 1층

w2 = np.array([6,7,8,9,10,11]).reshape(3,2)

m = np.dot(k_p,w2)
m_p = sigmoid(m)
print(m_p) # 은닉 2층

w3 = np.array([5,6,7,8]).reshape(2,2)
y = np.dot(m_p, w3)
print(y) # 출력값

def softmax(x):
    m = np.max(x)
    exp_x = np.exp(x-m)
    sum_exp_x = np.sum(exp_x)
    y = exp_x / sum_exp_x
    return y

y_p = softmax(y)
print(y_p) # 출력값의 확률벡터
print(sum(softmax(y_p)))
# Out:
# [0.99330715 0.9999833  0.99999996]
# [1. 1.]
# [12. 14.]
# [0.11920292 0.88079708]
# 1.0
